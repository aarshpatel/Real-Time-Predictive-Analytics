# %%
import csv

# %%
with open("../data/data.csv", "r") as f:
    reader = csv.reader(f, delimiter=",")
    reader.next()
    for row in reader:
        print(len(row))
# Out:
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# ...
